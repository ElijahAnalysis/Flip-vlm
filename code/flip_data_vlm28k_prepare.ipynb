# %%
# Core Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
from scipy import stats
from scipy.stats import randint, uniform

# %% [markdown]
# ## IMPORT & EXPLORE

# %%
flo_products = pd.read_csv(r"C:\Users\User\Downloads\flo\flo_products.csv")
all_products_combined = pd.read_csv(r"C:\Users\User\Downloads\flip_data_vlm_ext\all_products_combined.csv")
all_products_combinedv1 = pd.read_csv(r"C:\Users\User\Downloads\flip_data_vlm\flip_data_vlm\all_products_combined.csv")

# %%
flo_products.sample(10)
# Out:
#                           title  \
# 46      Мужской Кроссовки Синий
# 410   Мужской Кроссовки Зеленый
# 1691    Мужской Сандалии Черный
# 1394             Женский Черный
# 2006    Женский Кроссовки Серый
# 3249              Мужской Серый
# 893     Мужской Кроссовки Белый
# 1117     Мужской Тапочки Черный
# 145             Кроссовки Белый
# 220            Кроссовки Черный
#
#                                                     url  \
# 46    https://www.flo.com.kz/ru/product/kinetix-int1...
# 410   https://www.flo.com.kz/ru/product/adidas-barre...
# 1691  https://www.flo.com.kz/ru/product/flexall-int1...
# 1394  https://www.flo.com.kz/ru/product/polaris-int1...
# 2006  https://www.flo.com.kz/ru/product/reebok-club-...
# 3249  https://www.flo.com.kz/ru/product/kinetix-ml-i...
# 893   https://www.flo.com.kz/ru/product/lumberjack-l...
# 1117  https://www.flo.com.kz/ru/product/polaris-int1...
# 145   https://www.flo.com.kz/ru/product/nike-court-b...
# ...

# %%
all_products_combined.sample(10)
# Out:
#                                                  title  \
# 3863                              Коммутатор TL-SG1048
# 6573  Трусы-макси женские комплект, антрацит, 52RU/2XL
# 3983                                 Коммутатор LS1005
# 2871                     Wi-Fi точка доступа EAP265 HD
# 5092                             Набор проводной MF410
# 1729     Коврик игровой Bloody B-072, 27.5×22.5×0.4 см
# 6115               Пиджак женский, черный, 46RU - 50RU
# 1849                          Коммутатор USW-24-POE-EU
# 3056                   SSD накопитель SA400S37, 240 ГБ
# 3320            Набор фотобумаги матовой двухсторонней
#
#                                        local_image_path  \
# 3863  /root/flip/data/category_1/images/Коммутатор_T...
# 6573  /root/flip/data/category_2/images/Трусы_макси_...
# 3983  /root/flip/data/category_1/images/Коммутатор_L...
# 2871  /root/flip/data/category_1/images/Wi_Fi_точка_...
# 5092  /root/flip/data/category_1/images/Набор_провод...
# ...

# %%
all_products_combinedv1.sample(10)
# Out:
#                                                title  \
# 5435           Термокружка с компасом «Boss», черный
# 8018             Средство для смягчения воды, 750 мл
# 11556                                Свеча-цифра «1»
# 4022                                Топор мясорубный
# 12626                          Бутербродница КТ-1609
# 3522            Кроссовки для девочек, розовый, 30RU
# 6578                        Салфетки бумажные мягкие
# 11796  Порошок мыльный хозяйственный «Универсальный»
# 1182       Набор стаканов бумажных «Гербы Хогвартса»
# 6982                      Набор стаканов одноразовых
#
#                                         local_image_path  \
# 5435   /root/flip/data/category_1/images/Термокружка_...
# 8018   /root/flip/data/category_2/images/Средство_для...
# 11556  /root/flip/data/category_2/images/Свеча_цифра_...
# 4022   /root/flip/data/category_1/images/Топор_мясору...
# 12626  /root/flip/data/category_3/images/Бутербродниц...
# ...

# %% [markdown]
# ## CLEAN & PREPARE

# %%
all_products_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6616 entries, 0 to 6615
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             6616 non-null   object
#  1   local_image_path  6616 non-null   object
#  2   product_url       6616 non-null   object
# dtypes: object(3)
# memory usage: 155.2+ KB

# %%
flo_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3752 entries, 0 to 3751
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   3752 non-null   object
#  1   url     3752 non-null   object
#  2   image   3752 non-null   object
# dtypes: object(3)
# memory usage: 88.1+ KB

# %%
flo_products = flo_products.rename( columns = {"url" : "product_url", "image" : "local_image_path"} )

# %%
all_products_combined["local_image_path"] = (
    all_products_combined["local_image_path"]
    .str.replace("/root/flip/data/category_1/", "/root/flip/data/category_4/", regex=False)
    .str.replace("/root/flip/data/category_2/", "/root/flip/data/category_5/", regex=False)
)

# %%
flo_products["local_image_path"] = flo_products["local_image_path"].str.replace( "images/", "/flo_images/", regex = False )

# %%
all_products_combined_ext = pd.concat([all_products_combined, all_products_combinedv1, flo_products])

# %%
all_products_combined_ext.duplicated().sum()
# Out:
# 0

# %%
all_products_combined_ext.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28448 entries, 0 to 3751
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             28448 non-null  object
#  1   local_image_path  28447 non-null  object
#  2   product_url       28448 non-null  object
# dtypes: object(3)
# memory usage: 889.0+ KB

# %%
all_products_combined_ext.sample(20)
# Out:
#                                                   title  \
# 8360              Набор салфеток бумажных «Смола серая»
# 3732           Ремешок для браслета Xiaomi Smart Band 9
# 937               Беспроводные наушники внутриканальные
# 3002                     Шейкер электрический, молочный
# 4551                                Мяч «Ёжик» (8,5 см)
# 5840                     Нож многофункциональный 11 в 1
# 7426          Полотенце махровое «Graphics», 100×150 см
# 1532                            Мужской Кроссовки Синий
# 2157                    Bluetooth наушники Redmi Buds 3
# 12197                    Вентилятор беспроводной КТ-418
# 2931                              Мужской Шорты Зеленый
# 16999                          Вытяжка Fantasy Light 60
# 6351                                   Туалетная бумага
# 4182                    Коллаген гидролизованный, 125 г
# 6932              Набор свечей чайных «Long Life», 12 г
# 4098                           Маршрутизатор GT-AX11000
# ...

# %%
list(all_products_combined_ext["product_url"].sample(20))
# Out:
# ['https://www.flip.kz/catalog?prod=4083441',
#  'https://www.flip.kz/catalog?prod=4168458',
#  'https://www.flip.kz/catalog?prod=2784109',
#  'https://www.flip.kz/catalog?prod=4158835',
#  'https://www.flip.kz/catalog?prod=4869149',
#  'https://www.flip.kz/catalog?prod=1643060',
#  'https://www.flip.kz/catalog?prod=2913669',
#  'https://www.flo.com.kz/ru/product/reebok-reebok-basketball-heat-wa-black-man-449-102047863',
#  'https://www.flip.kz/catalog?prod=3133884',
#  'https://www.flip.kz/catalog?prod=2709044',
#  'https://www.flip.kz/catalog?prod=2586208',
#  'https://www.flip.kz/catalog?prod=3537285',
#  'https://www.flip.kz/catalog?prod=4228328',
#  'https://www.flip.kz/catalog?prod=2346651',
#  'https://www.flip.kz/catalog?prod=4107274',
#  'https://www.flip.kz/catalog?prod=3705029',
#  'https://www.flip.kz/catalog?prod=2554952',
#  'https://www.flip.kz/catalog?prod=4884579',
#  'https://www.flip.kz/catalog?prod=4254723',
#  'https://www.flip.kz/catalog?prod=4664568']

# %%
all_products_combined_ext.to_csv(r"C:\Users\User\Downloads\flip_data_vlm\flip_data_vlm\all_products_combined_ext.csv")
